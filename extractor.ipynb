# %%
from pathlib import Path
import shutil
from docling.document_converter import DocumentConverter

#récupérer le chemin actuel
cwd = Path.cwd()
docs = cwd / "docs"

#Récupérer les sous répertoires de docs
for i, sub_dir in enumerate(docs.iterdir()):
    #Pour chaque sous répertoire, récupérer et convertir les fichiers en .md
    if sub_dir.is_dir():
        name = sub_dir.name
        print(f"## {i+1}, {name}\n")
        #Vérifier si les noms de répertoires contiennent des espaces et les remplacer par des underscores
        if " " in name:
            name = name.replace(" ", "_")
            sub_dir.rename(sub_dir.parent / name)

        
        if (sub_dir / "markdowns").exists():
            shutil.rmtree(sub_dir / "markdowns")
        #créer un répertoir markdown
        Path.mkdir(sub_dir / "markdowns")

        #récuperer les fichiers de chaque sous répertoire et les convertir en .md
        for j, file in enumerate(sub_dir.iterdir()):
            if file.name == ".DS_Store":
                continue
            #vérifier qu'on a bien affaire à un répertoire
            if file.is_file():
                print(f"** - {j+1} - {file.name}")
                #prendre le même nom que le fichier originel pour la version markdown
                markdown_name = file.name.replace(".", "_")
                markdown_name += ".md"
                
                #initialiser le convertisseur
                converter = DocumentConverter()
                result = converter.convert(file)

                #Créer le fichier markdown et éccrire la version transrcite à l'intérieur
                markdown = result.document.export_to_markdown()
                markdown_file = Path(sub_dir / "markdowns" / markdown_name)
                markdown_file.write_text(markdown, encoding="utf-8")

                print("\n\n")
# Out:
# ## 2, projets
#
# ** - 1 - Projet de Création du Centre Culturel Innovant.pdf
# Loading weights: 100%|██████████| 770/770 [00:01<00:00, 707.46it/s]
# ** - 3 - Installation d'un système de surveillance urbaine.pdf
# Loading weights: 100%|██████████| 770/770 [00:00<00:00, 2034.05it/s]
# ** - 4 - projets_2024.csv
#
#
#
# ** - 5 - Projet de Rénovation de la Voirie Centrale.pdf
# Loading weights: 100%|██████████| 770/770 [00:00<00:00, 2350.03it/s]
# ** - 6 - Projet d'Amélioration des Espaces Verts.pdf
# Loading weights: 100%|██████████| 770/770 [00:00<00:00, 1707.22it/s]
# ** - 7 - Projet de Modernisation de l eclairage public.pdf
# Loading weights: 100%|██████████| 770/770 [00:00<00:00, 1066.86it/s]
# ** - 8 - Réaménagement de la place du Marché.pdf
# Loading weights: 100%|██████████| 770/770 [00:01<00:00, 612.31it/s]
# ** - 9 - Installation de panneaux photovoltaïques sur les bâtiments municipaux.pdf
# Loading weights: 100%|██████████| 770/770 [00:01<00:00, 704.28it/s]
# ** - 10 - Suivi du projet de Centre Culturel Innovant.pdf
# Loading weights: 100%|██████████| 770/770 [00:00<00:00, 1025.67it/s]
# ** - 11 - Développement de nouvelles pistes cyclables et zones piétonnes (2026).pdf
# Loading weights: 100%|██████████| 770/770 [00:01<00:00, 597.67it/s]
# ## 3, evenements
#
# ** - 1 - marche_noel_trifouillis_2023.png
# Loading weights: 100%|██████████| 770/770 [00:18<00:00, 42.33it/s]
# ** - 3 - Nuit des Arts Urbains.docx
#
#
#
# ** - 4 - Festival des Rires et des Blagues.docx
#
#
#
# ** - 5 - Le Carnaval des Objets Oubliés.docx
#
#
#
# ** - 6 - Journée de l’Insolence Créative.docx
#
#
#
# ** - 7 - Fête des Saveurs Insolites.docx
#
#
#
# ## 4, demandes_citoyennes
#
# ** - 1 - Signalement et demande d'intervention pour un éclairage public défectueux.docx
#
#
#
# ** - 2 - Demande d'information sur l'entretien de la voirie.docx
#
#
#
# ** - 3 - Demande de participation à la réunion municipale sur la revitalisation du centre-ville.docx
#
#
#
# ## 5, communication
#
# ** - 2 - voeux2025_trifouillis.wav
# /Users/cheick/Documents/repository/trifouillis-city-hal/.venv/lib/python3.12/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: French
# [00:00.000 --> 00:03.460]  J'ai appris fouillais, j'ai arrêté cette avec une grande émotion et niment
# [00:03.460 --> 00:07.900]  certé que je me tiens devant vous ce soir pour vous alercer mes veut, les plus
# [00:07.900 --> 00:12.640]  sincères en se débucdannées, l'année écoulée a été marqué par de nombreux défis.
# [00:13.580 --> 00:18.140]  Mais aussi par de belles avancées, pour notre commune nous ne pouvons ignorer le contexte
# [00:18.140 --> 00:24.160]  régionale et national qui demeure complice et parfois source d'acquétus, les pays
# [00:24.160 --> 00:29.000]  de la loi traversent une période de tension économique et social et nous sommes pleinement
# [00:29.000 --> 00:34.100]  conscients des préoccupations qui peuvent être les vôtre, mais je veux vous dire ici
# [00:34.100 --> 00:39.000]  avec force et conviction. Nous sommes une une soideaire et nous avons en nous toutes
# [00:39.000 --> 00:43.600]  les ressources pour faire face aux épreuves très foulis sur loi à toujours se relever
# [00:43.600 --> 00:48.880]  et avancer. Il ne fera pas exception chez que la fermeture de notre gare a sucité de
# [00:48.880 --> 00:53.560]  vivre inquiétude et je comprends votre attachement à ce service de transport et sa tienne.
# [00:53.720 --> 00:58.980]  Mais loin de voir cela, comme une régression, nous avons souhaité en faire une opportunité
# [00:58.980 --> 01:04.000]  pour notre ville des cet ânes éclifouillis sur loi, se detrait d'une flotte de l'us, électrique
# [01:04.000 --> 01:09.120]  moderne et accessible permettant de relier efficacement notre commune au Paul de transport,
# [01:09.540 --> 01:13.240]  régionale nous avons travaillé de main dans la main avec la région, et les autorités
# [01:13.240 --> 01:18.560]  de transport pour garantir une solution fiable et adate aux besoins de chacun soil
# [01:18.560 --> 01:22.640]  et assuré que nous continuerons à œuvrer, pour améliorer la mobilité et la
# [01:22.880 --> 01:25.320]  possibilité de notre territoire au-delà de cette transition.
# [01:26.100 --> 01:30.540]  sera une année placée sous le signe de l'innovation et du développement durable.
# [01:31.060 --> 01:35.380]  Nous poursuivrons un train gagement en faveur de l'écologie, avait de nouveaux projets d'aménagement
# [01:35.380 --> 01:39.920]  de rebahre de préservation de notre patrimoine naturelle et de soutien de Zini Settius,
# [01:40.200 --> 01:44.120]  locales-joutiens également à saluer l'engagement de nos associations de nos commerçants
# [01:44.120 --> 01:48.220]  de nos artisans et de toutes celles et ceux qui participent, t'attivement à la
# [01:48.220 --> 01:52.340]  ville notre commune très foulie sur loi. C'est avant toute une communauté soudée,
# [01:52.340 --> 01:54.880]  forte de son histoire et tournée vers la venir.
# [01:55.960 --> 02:02.000]  Ce début d'année, je veux vous arrêter un message de Timisme et d'espoir ensemble,
# [02:02.360 --> 02:07.080]  nous continuerons à bâtir une ville plus dynamique, plus soïdère et plus durable
# [02:07.080 --> 02:11.640]  je vous souhaite à toutes et à tous une très belle année, rempli de santé de bonheur
# [02:11.640 --> 02:16.100]  et de réussite viv très foulie sur le war et viv notre belle région et viv la
# [02:16.100 --> 02:16.360]  réputé.
#
#
#
# ** - 3 - logo_triffouillis.webp
# Loading weights: 100%|██████████| 770/770 [00:03<00:00, 229.50it/s]
# ** - 4 - Acceuil_affichage_Mairie de Triffouillis sur Loire.pdf
# Loading weights: 100%|██████████| 770/770 [00:00<00:00, 840.35it/s]
# ## 6, intances
#
# ** - 2 - Bulletin Municipal – Marché de Noël 2023.pdf
# Loading weights: 100%|██████████| 770/770 [00:00<00:00, 1306.04it/s]
# ** - 3 - RÈGLEMENT MUNICIPAL.pdf
# Loading weights: 100%|██████████| 770/770 [00:00<00:00, 843.76it/s]
# ** - 4 - PV_05102023.pdf
# Loading weights: 100%|██████████| 770/770 [00:10<00:00, 73.30it/s]
# ** - 5 - Bulletin Municipal – Réunion Publique.pdf
# Loading weights: 100%|██████████| 770/770 [00:10<00:00, 74.22it/s]
# ** - 6 - PV_20122023.pdf
# Loading weights: 100%|██████████| 770/770 [00:00<00:00, 796.91it/s]
# ** - 7 - Bulletin Municipal – Intervention Technique et Sécurité Routière.pdf
# Loading weights: 100%|██████████| 770/770 [00:00<00:00, 2374.01it/s]
# ** - 8 - PV_15112023.pdf
# Loading weights: 100%|██████████| 770/770 [00:00<00:00, 1381.60it/s]
# ## 7, budget
#
# ** - 2 - budget_2024.csv
